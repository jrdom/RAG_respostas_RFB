# %%
import fitz
import re

# %load_ext autoreload
# %autoreload 2

# %%
qna_irpf = fitz.open('P&R IRPF 2024 - v1.0 - 2024.05.03.pdf')

# %% [markdown]
# ### Regular expressions to handle each question

# %%
QUESTIONS_PROCESSING_PATTERNS={
    "NEW_QUESTION": "^([0-9]{3}[0-9]?)\s?[—–-]\s?(.+)",
    "MULTI_LINE_QUESTION":"^(.+\?)",
    "END_OF_QUESTION": "^Retorno ao sumário"
}

# %%
ANSWER_REFERENCES_PATTERN=".+\n\s?\((.+)\)\.?$|.+\n\s?\((.+)\)\.?\s*\n.*([Cc]onsulte.+pergunta.+)|.+([Cc]onsulte.+pergunta.+)$"

# %% [markdown]
# ### Functions to process a single page

# %%
def process_answer_body(which_answer):
    m = re.match (ANSWER_REFERENCES_PATTERN, "\n".join(which_answer), flags=re.DOTALL)

    references = ""
    linked_questions = ""
    end_of_answer_offset = 0
    
    if m is not None:
        if m.group(1) is not None:
            references = m.group(1)
            end_of_answer_offset = m.group(1).count('\n') + 1
            
        elif m.group(2) is not None:
            references = m.group(2)
            
            linked_questions = re.findall("\d+", m.group(3))

            end_of_answer_offset = m.group(2).count('\n') + m.group(3).count('\n') + 2
        elif m.group(4) is not None:
            linked_questions = re.findall("\d+", m.group(4))
            
            end_of_answer_offset = m.group(4).count('\n') + 1
            
    return {"answer_cleaned": which_answer[:-end_of_answer_offset] if end_of_answer_offset > 0 else which_answer,
            "references": references,
            "linked_questions": linked_questions}

# %%
def process_single_page(page_lines, 
                        current_question,
                        state,
                        processed_questions):

    for line in page_lines[2:]:
    
        m = re.match(QUESTIONS_PROCESSING_PATTERNS[state['current_pattern']], line)
    
        if m is not None:
            if state['current_pattern'] == "NEW_QUESTION":
                if len(m.groups()) > 0:
                    current_question['question_number'] = m.group(1)
                    current_question['question_summary'] = state['current_last_line']
                    current_question['question_text'] = m.group(2).strip()
                    current_question['answer'] = []

                    print("\n")
                    print(current_question)
                    print("\n")
                    
                    if current_question['question_text'][-1] != "?":
                        state['current_pattern'] = "MULTI_LINE_QUESTION"
                    else:
                        state['current_pattern'] = "END_OF_QUESTION"

                    print(f"Começo pergunta. questão={current_question['question_number']}")
            
            elif state['current_pattern'] == "MULTI_LINE_QUESTION":
                if len(m.groups()) > 0:
                    current_question['question_text'] += " " + m.group(1)
    
                    state['current_pattern'] = "END_OF_QUESTION"

                    print(f"Achou fim pergunta. questão={current_question['question_number']}")
                else:
                    current_question['question_text'] += " " + line
    
            elif state['current_pattern'] == "END_OF_QUESTION": 

                processed_answer = process_answer_body(current_question['answer'])

                current_question['answer_cleaned'] = processed_answer['answer_cleaned']
                current_question['references'] = processed_answer['references']
                current_question['linked_questions'] = processed_answer['linked_questions']
                
                processed_questions.append(current_question)

                print(f"Achou fim. questão={current_question['question_number']}. Total={len(processed_questions)}")

                current_question = {}
                state['current_pattern'] = "NEW_QUESTION"
        
            else:
                raise ValueError(f"Invalid pattern {state['current_pattern']}")
        else:
            if len(line.strip()) > 0:
                state['current_last_line'] = line.strip()
        
                if state['current_pattern'] == "END_OF_QUESTION":
                    current_question['answer'].append(line.strip())

    return current_question, processing_state

# %%
def print_questions(questions_list):
    for which_question in questions_list:
        print("\n-----------------------------------------------\n")
        print(f"Question number: {which_question['question_number']}")
        print(f"Question summary: {which_question['question_summary']}")
        print(f"Question text: {which_question['question_text']}\n")
        
        whole_answer = "\n".join(which_question['answer'])
        answer_cleaned = "\n".join(which_question['answer_cleaned'])
    
        print(f"Answer:\n{whole_answer}\n")
        print(f"Answer cleaned:\n{answer_cleaned}\n")
        print(f"References:\n{which_question['references']}\n")
        print(f"Linked questions:\n{which_question['linked_questions']}\n")

# %% [markdown]
# ## Extract the questions

# %%
questions = []
current_question = {}
processing_state={"current_pattern": "NEW_QUESTION",
                  "current_last_line": ""}

# %% [markdown]
# ### Loop through all the pages accumulating the extracted questions

# %%
for which_page in range(21, 300):
    current_question, processing_state = process_single_page(qna_irpf.load_page(which_page).get_text("text").split("\n"),
                                                             current_question,
                                                             processing_state,
                                                             questions)
# Out:
# {'question_number': '001', 'question_summary': 'OBRIGATORIEDADE', 'question_text': 'Quem está obrigado a apresentar a Declaração de Ajuste Anual relativa ao exercício de 2024,', 'answer': []}
#
#
# Começo pergunta. questão=001
# Achou fim pergunta. questão=001
# Achou fim. questão=001. Total=1
#
#
# {'question_number': '002', 'question_summary': 'PESSOA FÍSICA DESOBRIGADA', 'question_text': 'Pessoa física desobrigada pode apresentar a Declaração de Ajuste Anual (DAA)?', 'answer': []}
#
#
# Começo pergunta. questão=002
# Achou fim. questão=002. Total=2
#
#
# {'question_number': '003', 'question_summary': 'TITULAR OU SÓCIO DE EMPRESA', 'question_text': 'Contribuinte que é titular ou sócio de empresa está obrigado a apresentar a Declaração de', 'answer': []}
#
#
# Começo pergunta. questão=003
# Achou fim pergunta. questão=003
# Achou fim. questão=003. Total=3
#
#
# {'question_number': '004', 'question_summary': 'QUADRO SOCIETÁRIO OU ASSOCIADO DE COOPERATIVA', 'question_text': 'Contribuinte, que participou de quadro societário de sociedade anônima ou que foi associado', 'answer': []}
#
#
# Começo pergunta. questão=004
# Achou fim pergunta. questão=004
# Achou fim. questão=004. Total=4
#
#
# {'question_number': '005', 'question_summary': 'DE DECLARAR', 'question_text': 'Contribuinte que constou como responsável perante a Secretaria Especial da Receita Federal', 'answer': []}
#
#
# Começo pergunta. questão=005
# Achou fim pergunta. questão=005
# Achou fim. questão=005. Total=5
#
#
# {'question_number': '006', 'question_summary': 'LIMITE DE IDADE PARA DECLARAR', 'question_text': 'Existe limite de idade para a obrigatoriedade ou dispensa de apresentação da Declaração de', 'answer': []}
#
#
# Começo pergunta. questão=006
# Achou fim pergunta. questão=006
# Achou fim. questão=006. Total=6
#
#
# {'question_number': '007', 'question_summary': 'BENS E DIREITOS - AVALIAÇÃO', 'question_text': 'Para verificação da obrigatoriedade de apresentação da Declaração de Ajuste Anual, qual é o', 'answer': []}
#
#
# Começo pergunta. questão=007
# Achou fim pergunta. questão=007
# Achou fim. questão=007. Total=7
#
#
# {'question_number': '008', 'question_summary': 'BENS E DIREITOS - ATIVIDADE RURAL', 'question_text': 'A posse ou a propriedade de bens e direitos relativos à atividade rural de valor superior a', 'answer': []}
#
#
# Começo pergunta. questão=008
# Achou fim pergunta. questão=008
# Achou fim. questão=008. Total=8
#
#
# {'question_number': '009', 'question_summary': 'MAIS DE UMA FONTE PAGADORA', 'question_text': 'O contribuinte deve apresentar uma Declaração de Ajuste Anual para cada fonte pagadora', 'answer': []}
#
#
# Começo pergunta. questão=009
# Achou fim pergunta. questão=009
# Achou fim. questão=009. Total=9
#
#
# {'question_number': '010', 'question_summary': 'CADERNETA DE POUPANÇA SUPERIOR A R$ 800.000,00', 'question_text': 'Dependente que possui depósito em conta de poupança em valor superior a R$ 800.000,00', 'answer': []}
#
#
# Começo pergunta. questão=010
# Achou fim pergunta. questão=010
# Achou fim. questão=010. Total=10
#
#
# {'question_number': '011', 'question_summary': 'DOENÇA GRAVE', 'question_text': 'Contribuinte com doença grave está desobrigado de apresentar a declaração?', 'answer': []}
#
#
# Começo pergunta. questão=011
# Achou fim. questão=011. Total=11
#
#
# {'question_number': '012', 'question_summary': 'DESCONTO SIMPLIFICADO - CONCEITO', 'question_text': 'O que se considera como opção pelo desconto simplificado?', 'answer': []}
#
#
# Começo pergunta. questão=012
# Achou fim. questão=012. Total=12
#
#
# {'question_number': '013', 'question_summary': 'DESCONTO SIMPLIFICADO - DEPENDENTES COMUNS', 'question_text': 'Um cônjuge ou companheiro que apresenta declaração utilizando-se das deduções legais', 'answer': []}
#
#
# Começo pergunta. questão=013
# Achou fim pergunta. questão=013
# Achou fim. questão=013. Total=13
#
#
# {'question_number': '014', 'question_summary': 'DESCONTO SIMPLIFICADO - QUEM PODE OPTAR', 'question_text': 'Quem pode optar pelo desconto simplificado na apresentação da Declaração de Ajuste', 'answer': []}
#
#
# Começo pergunta. questão=014
# Achou fim pergunta. questão=014
# Achou fim. questão=014. Total=14
#
#
# {'question_number': '015', 'question_summary': 'MAIS DE UMA FONTE PAGADORA', 'question_text': 'O contribuinte que possui mais de uma fonte pagadora pode optar pelo desconto', 'answer': []}
#
#
# Começo pergunta. questão=015
# Achou fim pergunta. questão=015
# Achou fim. questão=015. Total=15
#
#
# {'question_number': '016', 'question_summary': 'PREJUÍZO NA ATIVIDADE RURAL — DESCONTO SIMPLIFICADO', 'question_text': 'O contribuinte que em 2023 recebeu rendimentos tributáveis na Declaração de Ajuste Anual', 'answer': []}
#
#
# Começo pergunta. questão=016
# Achou fim pergunta. questão=016
# Achou fim. questão=016. Total=16
#
#
# {'question_number': '017', 'question_summary': 'PAGAMENTOS E DOAÇÕES EFETUADOS', 'question_text': 'O contribuinte que optar pelo desconto simplificado deve preencher as fichas “Pagamentos', 'answer': []}
#
#
# Começo pergunta. questão=017
# Achou fim pergunta. questão=017
# Achou fim. questão=017. Total=17
#
#
# {'question_number': '018', 'question_summary': 'RENDIMENTOS ISENTOS - 65 ANOS OU MAIS', 'question_text': 'O desconto simplificado substitui a parcela de isenção referente a rendimentos de', 'answer': []}
#
#
# Começo pergunta. questão=018
# Achou fim pergunta. questão=018
# Achou fim. questão=018. Total=18
#
#
# {'question_number': '019', 'question_summary': 'RENDIMENTOS RECEBIDOS ACUMULADAMENTE (RRA)', 'question_text': 'O contribuinte que optar pelo desconto simplificado pode excluir os honorários advocatícios', 'answer': []}
#
#
# Começo pergunta. questão=019
# Achou fim pergunta. questão=019
# Achou fim. questão=019. Total=19
#
#
# {'question_number': '020', 'question_summary': 'ALUGUÉIS', 'question_text': 'O contribuinte que optar pelo desconto simplificado pode excluir as despesas com', 'answer': []}
#
#
# Começo pergunta. questão=020
# Achou fim pergunta. questão=020
# Achou fim. questão=020. Total=20
#
#
# {'question_number': '021', 'question_summary': 'DECLARAÇÃO DE AJUSTE ANUAL — EXERCÍCIO DE 2024', 'question_text': 'Qual é o prazo de apresentação da Declaração de Ajuste Anual do exercício de 2024?', 'answer': []}
#
#
# Começo pergunta. questão=021
# Achou fim. questão=021. Total=21
#
#
# {'question_number': '022', 'question_summary': 'DECLARANTE NO EXTERIOR', 'question_text': 'Qual é o prazo de apresentação da Declaração de Ajuste Anual para a pessoa física ausente', 'answer': []}
#
#
# Começo pergunta. questão=022
# Achou fim pergunta. questão=022
# Achou fim. questão=022. Total=22
#
#
# {'question_number': '023', 'question_summary': 'CONTRIBUINTE EM VIAGEM NA DATA DA APRESENTAÇÃO', 'question_text': 'Contribuinte que na data final da apresentação da declaração se encontra em viagem, fora de', 'answer': []}
#
#
# Começo pergunta. questão=023
# Achou fim pergunta. questão=023
# Achou fim. questão=023. Total=23
#
#
# {'question_number': '024', 'question_summary': 'MULTA POR ATRASO OU NÃO APRESENTAÇÃO - CONTRIBUINTE OBRIGADO A DECLARAR', 'question_text': 'Qual é a penalidade aplicável na apresentação da Declaração de Ajuste Anual depois do prazo', 'answer': []}
#
#
# Começo pergunta. questão=024
# Achou fim pergunta. questão=024
# Achou fim. questão=024. Total=24
#
#
# {'question_number': '025', 'question_summary': 'MULTA POR ATRASO OU NÃO APRESENTAÇÃO - CONTRIBUINTE NÃO OBRIGADO A DECLARAR', 'question_text': 'O contribuinte não obrigado à apresentação da Declaração de Ajuste Anual está sujeito à', 'answer': []}
#
#
# Começo pergunta. questão=025
# Achou fim pergunta. questão=025
# Achou fim. questão=025. Total=25
#
#
# {'question_number': '026', 'question_summary': 'FORMAS DE PREENCHIMENTO DO IRPF 2024', 'question_text': 'De quais formas posso preencher a Declaração de Ajuste Anual (DAA) do ano-calendário de', 'answer': []}
#
#
# Começo pergunta. questão=026
# Achou fim pergunta. questão=026
# Achou fim. questão=026. Total=26
#
#
# {'question_number': '027', 'question_summary': 'DECLARAÇÃO DE AJUSTE ANUAL – AUTORIZAÇÃO DE ACESSO', 'question_text': 'Quem pode apresentar a Declaração de Ajuste Anual em nome do contribuinte?', 'answer': []}
#
#
# Começo pergunta. questão=027
# Achou fim. questão=027. Total=27
#
#
# {'question_number': '028', 'question_summary': 'DECLARAÇÃO DE AJUSTE ANUAL PRÉ-PREENCHIDA – FORMAS DE ACESSO', 'question_text': 'Como acessar a Declaração de Ajuste Anual (DAA) Pré-Preenchida?', 'answer': []}
#
#
# Começo pergunta. questão=028
# Achou fim. questão=028. Total=28
#
#
# {'question_number': '029', 'question_summary': 'DECLARAÇÃO DE AJUSTE ANUAL PRÉ-PREENCHIDA – INFORMAÇÕES FORNECIDAS', 'question_text': 'Quais são as informações constantes na Declaração de Ajuste Anual Pré-Preenchida?', 'answer': []}
#
#
# Começo pergunta. questão=029
# Achou fim. questão=029. Total=29
#
#
# {'question_number': '030', 'question_summary': 'DECLARAÇÃO DE AJUSTE ANUAL PRÉ-PREENCHIDA – QUEM PODE UTILIZAR', 'question_text': 'Quem pode utilizar a Declaração de Ajuste Anual Pré-Preenchida?', 'answer': []}
#
#
# Começo pergunta. questão=030
# Achou fim. questão=030. Total=30
#
#
# {'question_number': '031', 'question_summary': '"MEU IMPOSTO DE RENDA" - VEDAÇÕES À SUA UTILIZAÇÃO', 'question_text': 'Quem não pode preencher ou apresentar a declaração por meio do “Meu Imposto de Renda”?', 'answer': []}
#
#
# Começo pergunta. questão=031
# Achou fim. questão=031. Total=31
#
#
# {'question_number': '032', 'question_summary': 'OBTENÇÃO DO PROGRAMA IRPF 2024', 'question_text': 'Onde obter o programa IRPF 2024?', 'answer': []}
#
#
# Começo pergunta. questão=032
# Achou fim. questão=032. Total=32
#
#
# {'question_number': '033', 'question_summary': 'EQUIPAMENTO NECESSÁRIO', 'question_text': 'Quais são os requisitos necessários para a utilização do programa IRPF 2024?', 'answer': []}
#
#
# Começo pergunta. questão=033
# Achou fim. questão=033. Total=33
#
#
# {'question_number': '034', 'question_summary': 'INSTALAÇÃO DO PROGRAMA IRPF 2024', 'question_text': 'Como instalar o programa IRPF 2024?', 'answer': []}
#
#
# Começo pergunta. questão=034
# Achou fim. questão=034. Total=34
#
#
# {'question_number': '035', 'question_summary': 'MEIOS DE TRANSMISSÃO DA DECLARAÇÃO', 'question_text': 'Quais são os meios a serem utilizados para transmissão da Declaração de Ajuste Anual do', 'answer': []}
#
#
# Começo pergunta. questão=035
# Achou fim pergunta. questão=035
# Achou fim. questão=035. Total=35
#
#
# {'question_number': '036', 'question_summary': 'OUTRAS INFORMAÇÕES', 'question_text': 'Onde obter outras informações sobre a transmissão da declaração pela Internet utilizando o', 'answer': []}
#
#
# Começo pergunta. questão=036
# Achou fim pergunta. questão=036
# Achou fim. questão=036. Total=36
#
#
# {'question_number': '037', 'question_summary': 'LOCAL DE APRESENTAÇÃO NO PRAZO', 'question_text': 'Qual o local de apresentação, no prazo, da Declaração de Ajuste Anual do exercício de 2024?', 'answer': []}
#
#
# Começo pergunta. questão=037
# Achou fim. questão=037. Total=37
#
#
# {'question_number': '038', 'question_summary': 'DECLARAÇÃO TRANSMITIDA COM A UTILIZAÇÃO DE CERTIFICADO DIGITAL', 'question_text': 'Quem deve transmitir a Declaração de Ajuste Anual do exercício de 2024 com a utilização de', 'answer': []}
#
#
# Começo pergunta. questão=038
# Achou fim pergunta. questão=038
# Achou fim. questão=038. Total=38
#
#
# {'question_number': '039', 'question_summary': 'DECLARANTE NO EXTERIOR', 'question_text': 'Qual é o local de apresentação da Declaração de Ajuste Anual para a pessoa física residente', 'answer': []}
#
#
# Começo pergunta. questão=039
# Achou fim pergunta. questão=039
# Achou fim. questão=039. Total=39
#
#
# {'question_number': '040', 'question_summary': 'APRESENTAÇÃO APÓS O PRAZO', 'question_text': 'Qual é o local de apresentação da Declaração de Ajuste Anual do exercício de 2024', 'answer': []}
#
#
# Começo pergunta. questão=040
# Achou fim pergunta. questão=040
# Achou fim. questão=040. Total=40
#
#
# {'question_number': '041', 'question_summary': 'AGÊNCIAS BANCÁRIAS AUTORIZADAS', 'question_text': 'Em quais instituições financeiras podem ser apresentadas a Declaração de Ajuste Anual de', 'answer': []}
#
#
# Começo pergunta. questão=041
# Achou fim pergunta. questão=041
# Achou fim. questão=041. Total=41
#
#
# {'question_number': '042', 'question_summary': 'DECLARAÇÕES E PROGRAMAS IRPF DE EXERCÍCIOS ANTERIORES', 'question_text': 'Como apresentar as declarações de anos anteriores?', 'answer': []}
#
#
# Começo pergunta. questão=042
# Achou fim. questão=042. Total=42
#
#
# {'question_number': '043', 'question_summary': 'RETIFICAÇÃO', 'question_text': 'O contribuinte pode retificar sua declaração de rendimentos?', 'answer': []}
#
#
# Começo pergunta. questão=043
# Achou fim. questão=043. Total=43
#
#
# {'question_number': '044', 'question_summary': 'RETIFICAÇÃO - PRAZO', 'question_text': 'Há limite de prazo para a retificação da declaração?', 'answer': []}
#
#
# Começo pergunta. questão=044
# Achou fim. questão=044. Total=44
#
#
# {'question_number': '045', 'question_summary': 'DECLARAÇÃO RETIFICADORA - ONDE APRESENTAR', 'question_text': 'Onde deve ser apresentada a declaração retificadora?', 'answer': []}
#
#
# Começo pergunta. questão=045
# Achou fim. questão=045. Total=45
#
#
# {'question_number': '046', 'question_summary': 'DECLARAÇÃO RETIFICADORA - TROCA DE OPÇÃO', 'question_text': 'O contribuinte pode retificar sua declaração para troca da opção da forma de tributação?', 'answer': []}
#
#
# Começo pergunta. questão=046
# Achou fim. questão=046. Total=46
#
#
# {'question_number': '047', 'question_summary': 'DESCONTO SIMPLIFICADO - PREJUÍZO NA ATIVIDADE RURAL', 'question_text': 'O contribuinte pode retificar a sua declaração, relativa ao ano-calendário de 2023, a fim de', 'answer': []}
#
#
# Começo pergunta. questão=047
# Achou fim pergunta. questão=047
# Achou fim. questão=047. Total=47
#
#
# {'question_number': '048', 'question_summary': 'RETIFICAÇÃO - EXERCÍCIOS ANTERIORES', 'question_text': 'Como proceder quando a declaração retificadora for relativa a exercícios anteriores?', 'answer': []}
#
#
# Começo pergunta. questão=048
# Achou fim. questão=048. Total=48
#
#
# {'question_number': '049', 'question_summary': 'DECLARAÇÃO DO CÔNJUGE - ALTERAÇÕES', 'question_text': 'Como proceder quando a declaração retificadora do contribuinte implicar modificações na', 'answer': []}
#
#
# Começo pergunta. questão=049
# Achou fim pergunta. questão=049
# Achou fim. questão=049. Total=49
#
#
# {'question_number': '050', 'question_summary': 'IMPOSTO - PAGAMENTO', 'question_text': 'Como proceder quanto ao pagamento do imposto após a declaração retificadora?', 'answer': []}
#
#
# Começo pergunta. questão=050
# Achou fim. questão=050. Total=50
#
#
# {'question_number': '051', 'question_summary': 'IMPOSTO - MUDANÇA NA FORMA DE PAGAMENTO', 'question_text': 'Contribuinte que tenha optado pelo pagamento do imposto à vista deve retificar a declaração,', 'answer': []}
#
#
# Começo pergunta. questão=051
# Achou fim pergunta. questão=051
# Achou fim. questão=051. Total=51
#
#
# {'question_number': '052', 'question_summary': 'APOSENTADO COM 65 ANOS OU MAIS - ISENÇÃO', 'question_text': 'Contribuinte, com 65 anos ou mais, que não utilizou na declaração a parcela de isenção', 'answer': []}
#
#
# Começo pergunta. questão=052
# Achou fim pergunta. questão=052
# Achou fim. questão=052. Total=52
#
#
# {'question_number': '053', 'question_summary': 'PDV - PROGRAMA DE DEMISSÃO VOLUNTÁRIA', 'question_text': 'Como deve proceder o contribuinte que sofreu retenção na fonte sobre verbas especiais', 'answer': []}
#
#
# Começo pergunta. questão=053
# Achou fim pergunta. questão=053
# Achou fim. questão=053. Total=53
#
#
# {'question_number': '054', 'question_summary': 'DECLARAÇÃO DE BENS OU DE DÍVIDAS E ÔNUS - ERROS', 'question_text': 'Erros na Declaração de Bens e Direitos ou na Declaração de Dívidas e Ônus Reais, que não', 'answer': []}
#
#
# Começo pergunta. questão=054
# Achou fim pergunta. questão=054
# Achou fim. questão=054. Total=54
#
#
# {'question_number': '055', 'question_summary': 'COMPROVANTE ERRADO OU NÃO ENTREGUE', 'question_text': 'Qual é o procedimento a ser adotado pela pessoa física quando a fonte pagadora não lhe', 'answer': []}
#
#
# Começo pergunta. questão=055
# Achou fim pergunta. questão=055
# Achou fim. questão=055. Total=55
#
#
# {'question_number': '056', 'question_summary': 'FALTA DE COMPROVANTE DE FONTE PAGADORA', 'question_text': 'Contribuinte que auferiu rendimentos diversos, mas que não possui comprovantes de todas', 'answer': []}
#
#
# Começo pergunta. questão=056
# Achou fim pergunta. questão=056
# Achou fim. questão=056. Total=56
#
#
# {'question_number': '057', 'question_summary': 'PENALIDADE À FONTE PAGADORA', 'question_text': 'Quais as penalidades a que estão sujeitas as fontes pagadoras que deixarem de fornecer ou', 'answer': []}
#
#
# Começo pergunta. questão=057
# Achou fim pergunta. questão=057
# Achou fim. questão=057. Total=57
#
#
# {'question_number': '058', 'question_summary': 'NÃO RESIDENTE', 'question_text': 'A pessoa física não residente no Brasil está obrigada à inscrição no Cadastro de Pessoas', 'answer': []}
#
#
# Começo pergunta. questão=058
# Achou fim pergunta. questão=058
# Achou fim. questão=058. Total=58
#
#
# {'question_number': '059', 'question_summary': 'DEPENDENTE - OBRIGATORIEDADE DE INSCRIÇÃO NO CADASTRO DE PESSOAS FÌSICAS (CPF)', 'question_text': 'É obrigatória a inscrição no Cadastro de Pessoas Físicas (CPF) de dependente relacionado', 'answer': []}
#
#
# Começo pergunta. questão=059
# Achou fim pergunta. questão=059
# Achou fim. questão=059. Total=59
#
#
# {'question_number': '060', 'question_summary': 'CÓPIA DA DECLARAÇÃO DE AJUSTE ANUAL', 'question_text': 'Como deve proceder o contribuinte que perdeu a cópia da Declaração de Ajuste Anual do ano', 'answer': []}
#
#
# Começo pergunta. questão=060
# Achou fim pergunta. questão=060
# Achou fim. questão=060. Total=60
#
#
# {'question_number': '061', 'question_summary': 'CÁLCULO DO IMPOSTO — TABELA', 'question_text': 'Qual é a tabela a ser aplicada para o cálculo do imposto sobre a renda na Declaração de', 'answer': []}
#
#
# Começo pergunta. questão=061
# Achou fim pergunta. questão=061
# Achou fim. questão=061. Total=61
#
#
# {'question_number': '062', 'question_summary': 'BASE DE CÁLCULO', 'question_text': 'O que se considera base de cálculo do imposto sobre a renda a ser apurado na declaração?', 'answer': []}
#
#
# Começo pergunta. questão=062
# Achou fim. questão=062. Total=62
#
#
# {'question_number': '063', 'question_summary': 'PAGAMENTO DO IMPOSTO', 'question_text': 'O imposto apurado na Declaração de Ajuste Anual do exercício de 2024, ano-calendário de', 'answer': []}
#
#
# Começo pergunta. questão=063
# Achou fim pergunta. questão=063
# Achou fim. questão=063. Total=63
#
#
# {'question_number': '064', 'question_summary': 'PAGAMENTO DAS QUOTAS DO IRPF', 'question_text': 'Como efetuar o cálculo do pagamento das quotas de IRPF?', 'answer': []}
#
#
# Começo pergunta. questão=064
# Achou fim. questão=064. Total=64
#
#
# {'question_number': '065', 'question_summary': 'LOCAL DE PAGAMENTO DAS QUOTAS DO IRPF', 'question_text': 'Contribuinte residente em um estado pode efetuar o pagamento do imposto sobre a renda em', 'answer': []}
#
#
# Começo pergunta. questão=065
# Achou fim pergunta. questão=065
# Achou fim. questão=065. Total=65
#
#
# {'question_number': '066', 'question_summary': 'FORMAS DE PAGAMENTO DO IMPOSTO', 'question_text': 'Como pagar o imposto e seus respectivos acréscimos legais?', 'answer': []}
#
#
# Começo pergunta. questão=066
# Achou fim. questão=066. Total=66
#
#
# {'question_number': '067', 'question_summary': 'PERDA DO DARF', 'question_text': 'Como deve proceder o contribuinte que perdeu o Darf de recolhimento?', 'answer': []}
#
#
# Começo pergunta. questão=067
# Achou fim. questão=067. Total=67
#
#
# {'question_number': '068', 'question_summary': 'CORREÇÃO MONETÁRIA', 'question_text': 'Há correção monetária na restituição ou compensação de imposto pago a maior ou', 'answer': []}
#
#
# Começo pergunta. questão=068
# Achou fim pergunta. questão=068
# Achou fim. questão=068. Total=68
#
#
# {'question_number': '069', 'question_summary': 'IR PAGO INDEVIDAMENTE', 'question_text': 'Qual é o prazo para pleitear a restituição do imposto sobre a renda pago indevidamente?', 'answer': []}
#
#
# Começo pergunta. questão=069
# Achou fim. questão=069. Total=69
#
#
# {'question_number': '070', 'question_summary': 'RESTITUIÇÃO – CRÉDITO EM CONTA-CORRENTE OU DE POUPANÇA', 'question_text': 'A restituição só pode ser creditada em conta bancária?', 'answer': []}
#
#
# Começo pergunta. questão=070
# Achou fim. questão=070. Total=70
#
#
# {'question_number': '071', 'question_summary': 'RESTITUIÇÃO - CONTA CONJUNTA', 'question_text': 'No caso de conta conjunta, ambos os contribuintes podem indicá-la para o recebimento da', 'answer': []}
#
#
# Começo pergunta. questão=071
# Achou fim pergunta. questão=071
# Achou fim. questão=071. Total=71
#
#
# {'question_number': '072', 'question_summary': 'RESTITUIÇÃO - CONTA DE TERCEIROS', 'question_text': 'É possível autorizar o crédito da restituição em conta de terceiros?', 'answer': []}
#
#
# Começo pergunta. questão=072
# Achou fim. questão=072. Total=72
#
#
# {'question_number': '073', 'question_summary': 'RESTITUIÇÃO - ALTERAÇÃO NA CONTA INDICADA', 'question_text': 'É possível alterar a conta indicada para o crédito da restituição?', 'answer': []}
#
#
# Começo pergunta. questão=073
# Achou fim. questão=073. Total=73
#
#
# {'question_number': '074', 'question_summary': 'RESTITUIÇÃO - DECLARANTE NO EXTERIOR', 'question_text': 'Como é feita a restituição para os declarantes no exterior?', 'answer': []}
#
#
# Começo pergunta. questão=074
# Achou fim. questão=074. Total=74
#
#
# {'question_number': '075', 'question_summary': 'RESTITUIÇÃO – PRIORIDADE NO RECEBIMENTO', 'question_text': 'Quais os critérios legais referentes à priorização para o recebimento das restituições?', 'answer': []}
#
#
# Começo pergunta. questão=075
# Achou fim. questão=075. Total=75
#
#
# {'question_number': '076', 'question_summary': 'RESTITUIÇÃO – LOTES DE PAGAMENTO', 'question_text': 'Qual o calendário de pagamento dos lotes de restituição?', 'answer': []}
#
#
# Começo pergunta. questão=076
# Achou fim. questão=076. Total=76
#
#
# {'question_number': '077', 'question_summary': 'CONTRIBUINTE CASADO', 'question_text': 'Como declara o contribuinte casado?', 'answer': []}
#
#
# Começo pergunta. questão=077
# Achou fim. questão=077. Total=77
#
#
# {'question_number': '078', 'question_summary': 'BENS ADQUIRIDOS EM CONDOMÍNIO ANTES DO CASAMENTO', 'question_text': 'Qual é o tratamento tributário dos rendimentos produzidos pelos bens adquiridos em', 'answer': []}
#
#
# Começo pergunta. questão=078
# Achou fim pergunta. questão=078
# Achou fim. questão=078. Total=78
#
#
# {'question_number': '079', 'question_summary': 'CONTRIBUINTE QUE TENHA COMPANHEIRO(A)', 'question_text': 'Como deve declarar o contribuinte que tenha companheiro(a)?', 'answer': []}
#
#
# Começo pergunta. questão=079
# Achou fim. questão=079. Total=79
#
#
# {'question_number': '080', 'question_summary': 'CONTRIBUINTE DIVORCIADO QUE SE CASOU NOVAMENTE', 'question_text': 'Como deve declarar o contribuinte divorciado que tenha se casado novamente?', 'answer': []}
#
#
# Começo pergunta. questão=080
# Achou fim. questão=080. Total=80
#
#
# {'question_number': '081', 'question_summary': 'CONTRIBUINTE SEPARADO DE FATO', 'question_text': 'Como deve declarar o contribuinte separado de fato?', 'answer': []}
#
#
# Começo pergunta. questão=081
# Achou fim. questão=081. Total=81
#
#
# {'question_number': '0820', 'question_summary': 'CONTRIBUINTE DIVORCIADO OU SEPARADO JUDICIALMENTE OU POR ESCRITURA PÚBLICA', 'question_text': 'Como deve declarar o contribuinte divorciado ou separado judicialmente ou por escritura', 'answer': []}
#
#
# Começo pergunta. questão=0820
# Achou fim pergunta. questão=0820
# Achou fim. questão=0820. Total=82
#
#
# {'question_number': '083', 'question_summary': 'CONTRIBUINTE VIÚVO', 'question_text': 'Como deve declarar o contribuinte viúvo no decorrer do inventário?', 'answer': []}
#
#
# Começo pergunta. questão=083
# Achou fim. questão=083. Total=83
#
#
# {'question_number': '084', 'question_summary': 'CONTRIBUINTE MENOR', 'question_text': 'Como deve declarar o contribuinte menor?', 'answer': []}
#
#
# Começo pergunta. questão=084
# Achou fim. questão=084. Total=84
#
#
# {'question_number': '085', 'question_summary': 'CONTRIBUINTE MENOR EMANCIPADO', 'question_text': 'Como deve declarar o contribuinte menor emancipado?', 'answer': []}
#
#
# Começo pergunta. questão=085
# Achou fim. questão=085. Total=85
#
#
# {'question_number': '086', 'question_summary': 'CONTRIBUINTE INCAPAZ', 'question_text': 'Como deve declarar o contribuinte incapaz?', 'answer': []}
#
#
# Começo pergunta. questão=086
# Achou fim. questão=086. Total=86
#
#
# {'question_number': '087', 'question_summary': 'DECLARANTE EM CONJUNTO - CONCEITO', 'question_text': 'Quem é considerado declarante em conjunto?', 'answer': []}
#
#
# Começo pergunta. questão=087
# Achou fim. questão=087. Total=87
#
#
# {'question_number': '088', 'question_summary': 'CÔNJUGE OU FILHO (NA CONDIÇÃO DE DEPENDENTE)', 'question_text': 'Cônjuge e filho podem apresentar a declaração de rendimentos em conjunto ou, sem', 'answer': []}
#
#
# Começo pergunta. questão=088
# Achou fim pergunta. questão=088
# Achou fim. questão=088. Total=88
#
#
# {'question_number': '089', 'question_summary': 'COMPENSAÇÃO DO IR - BENS EM CONDOMÍNIO OU COMUNHÃO', 'question_text': 'O imposto referente a aluguel de imóvel possuído em condomínio ou em decorrência da', 'answer': []}
#
#
# Começo pergunta. questão=089
# Achou fim pergunta. questão=089
# Achou fim. questão=089. Total=89
#
#
# {'question_number': '090', 'question_summary': 'CONCEITO', 'question_text': 'O que é espólio?', 'answer': []}
#
#
# Começo pergunta. questão=090
# Achou fim. questão=090. Total=90
#
#
# {'question_number': '091', 'question_summary': 'PESSOA FALECIDA - IMPOSTO SOBRE A RENDA DEVIDO', 'question_text': 'É devido imposto sobre a renda de contribuinte que faleceu após a apresentação da', 'answer': []}
#
#
# Começo pergunta. questão=091
# Achou fim pergunta. questão=091
# Achou fim. questão=091. Total=91
#
#
# {'question_number': '092', 'question_summary': 'PESSOA FALECIDA - RESTITUIÇÃO DO IMPOSTO SOBRE A RENDA', 'question_text': 'É dispensável o alvará judicial na restituição, ao cônjuge viúvo ou aos herdeiros do falecido,', 'answer': []}
#
#
# Começo pergunta. questão=092
# Achou fim pergunta. questão=092
# Achou fim. questão=092. Total=92
#
#
# {'question_number': '093', 'question_summary': 'FALECIMENTO - BENS A INVENTARIAR', 'question_text': 'Qual é o procedimento a ser adotado no caso de falecimento, no ano-calendário de 2023, de', 'answer': []}
#
#
# Começo pergunta. questão=093
# Achou fim pergunta. questão=093
# Achou fim. questão=093. Total=93
#
#
# {'question_number': '094', 'question_summary': 'DECLARAÇÕES DE ESPÓLIO', 'question_text': 'O que se considera declaração inicial, intermediária e final de espólio?', 'answer': []}
#
#
# Começo pergunta. questão=094
# Achou fim. questão=094. Total=94
#
#
# {'question_number': '095', 'question_summary': 'DECLARAÇÃO FINAL DE ESPÓLIO - OBRIGATORIEDADE', 'question_text': 'Se o espólio não estava obrigado a apresentar as declarações inicial e intermediárias,', 'answer': []}
#
#
# Começo pergunta. questão=095
# Achou fim pergunta. questão=095
# Achou fim. questão=095. Total=95
#
#
# {'question_number': '096', 'question_summary': 'BENS COMUNS - RENDIMENTOS', 'question_text': 'Como o espólio declara os rendimentos referentes aos bens comuns?', 'answer': []}
#
#
# Começo pergunta. questão=096
# Achou fim. questão=096. Total=96
#
#
# {'question_number': '097', 'question_summary': 'SOBREPARTILHA - BENS', 'question_text': 'Que bens são passíveis de sobrepartilha?', 'answer': []}
#
#
# Começo pergunta. questão=097
# Achou fim. questão=097. Total=97
#
#
# {'question_number': '098', 'question_summary': 'DECLARAÇÕES DE ESPÓLIO - DEDUÇÕES', 'question_text': 'Que deduções são permitidas nas declarações do espólio?', 'answer': []}
#
#
# Começo pergunta. questão=098
# Achou fim. questão=098. Total=98
#
#
# {'question_number': '099', 'question_summary': 'DEPENDENTES', 'question_text': 'Os mesmos dependentes podem constar na Declaração Final de Espólio e também na', 'answer': []}
#
#
# Começo pergunta. questão=099
# Achou fim pergunta. questão=099
# Achou fim. questão=099. Total=99
#
#
# {'question_number': '100', 'question_summary': 'FUNERAL, TAXAS, HONORÁRIOS ADVOCATÍCIOS - DEDUÇÕES', 'question_text': 'São dedutíveis nas declarações de espólio os gastos com funeral, taxas, emolumentos e', 'answer': []}
#
#
# Começo pergunta. questão=100
# Achou fim pergunta. questão=100
# Achou fim. questão=100. Total=100
#
#
# {'question_number': '101', 'question_summary': 'DECLARAÇÕES DE ESPÓLIO - APRESENTAÇÃO', 'question_text': 'Quem deve apresentar as declarações de espólio?', 'answer': []}
#
#
# Começo pergunta. questão=101
# Achou fim. questão=101. Total=101
#
#
# {'question_number': '102', 'question_summary': 'DECLARAÇÃO DE ESPÓLIO - NÃO RESIDENTE NO BRASIL', 'question_text': 'Devem ser apresentadas as declarações de espólio de pessoa não residente no Brasil?', 'answer': []}
#
#
# Começo pergunta. questão=102
# Achou fim. questão=102. Total=102
#
#
# {'question_number': '103', 'question_summary': 'OBRIGAÇÃO TRIBUTÁRIA TRANSFERIDA A HERDEIROS', 'question_text': 'Incidem acréscimos legais quando a responsabilidade pela obrigação tributária do espólio', 'answer': []}
#
#
# Começo pergunta. questão=103
# Achou fim pergunta. questão=103
# Achou fim. questão=103. Total=103
#
#
# {'question_number': '104', 'question_summary': 'FALECIMENTO DE AMBOS OS CÔNJUGES', 'question_text': 'Como devem ser apresentadas as declarações de espólio no caso de ocorrência de morte de', 'answer': []}
#
#
# Começo pergunta. questão=104
# Achou fim pergunta. questão=104
# Achou fim. questão=104. Total=104
#
#
# {'question_number': '105', 'question_summary': 'INVENTÁRIO - NOVOS BENS ANTES DA PARTILHA', 'question_text': 'Como proceder no caso de serem trazidos novos bens ao inventário antes do trânsito em', 'answer': []}
#
#
# Começo pergunta. questão=105
# Achou fim pergunta. questão=105
# Achou fim. questão=105. Total=105
#
#
# {'question_number': '106', 'question_summary': 'INVENTÁRIO - NOVOS BENS APÓS PARTILHA', 'question_text': 'Como proceder no caso de novos bens serem trazidos ao inventário após o trânsito em', 'answer': []}
#
#
# Começo pergunta. questão=106
# Achou fim pergunta. questão=106
# Achou fim. questão=106. Total=106
#
#
# {'question_number': '107', 'question_summary': 'DECLARAÇÃO FINAL DE ESPÓLIO - PRAZO DE APRESENTAÇÃO/PAGAMENTO DO IMPOSTO', 'question_text': 'Qual é o prazo para a apresentação da Declaração Final de Espólio?', 'answer': []}
#
#
# Começo pergunta. questão=107
# Achou fim. questão=107. Total=107
#
#
# {'question_number': '108', 'question_summary': 'DECLARAÇÃO FINAL DE ESPÓLIO - APURAÇÃO DO IMPOSTO', 'question_text': 'Como apurar o imposto na Declaração Final de Espólio?', 'answer': []}
#
#
# Começo pergunta. questão=108
# Achou fim. questão=108. Total=108
#
#
# {'question_number': '109', 'question_summary': 'DECLARAÇÃO FINAL DE ESPÓLIO - DECLARAÇÃO DE BENS', 'question_text': 'Como deve ser preenchida a Declaração de Bens e Direitos da Declaração Final de Espólio?', 'answer': []}
#
#
# Começo pergunta. questão=109
# Achou fim. questão=109. Total=109
#
#
# {'question_number': '110', 'question_summary': 'TRANSFERÊNCIA DE BENS E DIREITOS', 'question_text': 'Qual é o tratamento tributário aplicável à transferência de bens e direitos a herdeiros ou', 'answer': []}
#
#
# Começo pergunta. questão=110
# Achou fim pergunta. questão=110
# Achou fim. questão=110. Total=110
#
#
# {'question_number': '111', 'question_summary': 'BENS DOADOS EM VIDA', 'question_text': 'Os bens doados em vida respondem pelas dívidas fiscais do espólio?', 'answer': []}
#
#
# Começo pergunta. questão=111
# Achou fim. questão=111. Total=111
#
#
# {'question_number': '112', 'question_summary': 'MOLÉSTIA GRAVE – PROVENTOS E PENSÕES RECEBIDOS PELO ESPÓLIO OU HERDEIROS', 'question_text': 'Qual é o tratamento tributário dos proventos de aposentadoria ou reforma e valores a título', 'answer': []}
#
#
# Começo pergunta. questão=112
# Achou fim pergunta. questão=112
# Achou fim. questão=112. Total=112
#
#
# {'question_number': '113', 'question_summary': 'BASES DA TRIBUTAÇÃO DA PESSOA FÍSICA', 'question_text': 'Quais rendimentos recebidos de fontes no exterior por residentes no Brasil ou recebidos de', 'answer': []}
#
#
# Começo pergunta. questão=113
# Achou fim pergunta. questão=113
# Achou fim. questão=113. Total=113
#
#
# {'question_number': '114', 'question_summary': 'RESIDENTE NO BRASIL - CONCEITO', 'question_text': 'Qual é o conceito de residente no Brasil para fins de tributação pelo imposto sobre a renda', 'answer': []}
#
#
# Começo pergunta. questão=114
# Achou fim pergunta. questão=114
# Achou fim. questão=114. Total=114
#
#
# {'question_number': '115', 'question_summary': 'NÃO RESIDENTE NO BRASIL - CONCEITO', 'question_text': 'Quem é considerado não residente no Brasil para fins de tributação pelo imposto sobre a', 'answer': []}
#
#
# Começo pergunta. questão=115
# Achou fim pergunta. questão=115
# Achou fim. questão=115. Total=115
#
#
# {'question_number': '116', 'question_summary': 'RESIDENTE', 'question_text': 'Quando se inicia nova contagem para estabelecer a condição de residente ou de não residente', 'answer': []}
#
#
# Começo pergunta. questão=116
# Achou fim pergunta. questão=116
# Achou fim. questão=116. Total=116
#
#
# {'question_number': '117', 'question_summary': 'SAÍDA TEMPORÁRIA - PROCEDIMENTOS', 'question_text': 'Como deve proceder a pessoa física residente que se ausentar do Brasil em caráter', 'answer': []}
#
#
# Começo pergunta. questão=117
# Achou fim pergunta. questão=117
# Achou fim. questão=117. Total=117
#
#
# {'question_number': '118', 'question_summary': 'SAÍDA TEMPORÁRIA - TRIBUTAÇÃO', 'question_text': 'Como são tributados os rendimentos recebidos pela pessoa física que se ausentar do Brasil', 'answer': []}
#
#
# Começo pergunta. questão=118
# Achou fim pergunta. questão=118
# Achou fim. questão=118. Total=118
#
#
# {'question_number': '119', 'question_summary': 'SAÍDA DEFINITIVA - PROCEDIMENTOS', 'question_text': 'Como deve proceder a pessoa física residente que se retirar em caráter permanente do Brasil?', 'answer': []}
#
#
# Começo pergunta. questão=119
# Achou fim. questão=119. Total=119
#
#
# {'question_number': '120', 'question_summary': 'SAÍDA DEFINITIVA E RETORNO AO BRASIL', 'question_text': 'Quem esteve ausente do Brasil por vários anos, perdendo a condição de residente, poderá', 'answer': []}
#
#
# Começo pergunta. questão=120
# Achou fim pergunta. questão=120
# Achou fim. questão=120. Total=120
#
#
# {'question_number': '121', 'question_summary': 'DECLARAÇÃO DE SAÍDA DEFINITIVA DO PAÍS – APURAÇÃO DO IMPOSTO', 'question_text': 'Como é apurado o imposto sobre a renda na Declaração de Saída Definitiva do País?', 'answer': []}
#
#
# Começo pergunta. questão=121
# Achou fim. questão=121. Total=121
#
#
# {'question_number': '122', 'question_summary': 'DECLARAÇÃO DE SAÍDA DEFINITIVA DO PAÍS – RESTITUIÇÃO DO IMPOSTO', 'question_text': 'Como receber uma restituição apurada na Declaração de Saída Definitiva do País?', 'answer': []}
#
#
# Começo pergunta. questão=122
# Achou fim. questão=122. Total=122
#
#
# {'question_number': '123', 'question_summary': 'DECLARAÇÃO DE SAÍDA DEFINITIVA DO PAÍS – BASE DE CÁLCULO', 'question_text': 'Como é determinada a base de cálculo do imposto na Declaração de Saída Definitiva do País?', 'answer': []}
#
#
# Começo pergunta. questão=123
# Achou fim. questão=123. Total=123
#
#
# {'question_number': '124', 'question_summary': 'DECLARAÇÃO DE SAÍDA DEFINITIVA DO PAÍS – DEDUÇÕES EM MOEDA ESTRANGEIRA', 'question_text': 'Como devem ser informadas as deduções de pagamentos efetuados em moeda estrangeira', 'answer': []}
#
#
# Começo pergunta. questão=124
# Achou fim pergunta. questão=124
# Achou fim. questão=124. Total=124
#
#
# {'question_number': '125', 'question_summary': 'RESIDENTE - SAÍDA TEMPORÁRIA OU DEFINITIVA SEM APRESENTAÇÃO DE COMUNICAÇÃO', 'question_text': 'Como é considerada a pessoa física que se retire em caráter temporário do Brasil ou, se em', 'answer': []}
#
#
# Começo pergunta. questão=125
# Achou fim pergunta. questão=125
# Achou fim. questão=125. Total=125
#
#
# {'question_number': '126', 'question_summary': 'NÃO RESIDENTE - VISTO TEMPORÁRIO', 'question_text': 'Qual é o regime de tributação do imposto sobre a renda aplicável à pessoa física não residente', 'answer': []}
#
#
# Começo pergunta. questão=126
# Achou fim pergunta. questão=126
# Achou fim. questão=126. Total=126
#
#
# {'question_number': '127', 'question_summary': 'BRASILEIRO, NÃO RESIDENTE, QUE RETORNA AO BRASIL', 'question_text': 'Brasileiro, não residente, que retorna ao território nacional readquire de imediato a condição', 'answer': []}
#
#
# Começo pergunta. questão=127
# Achou fim pergunta. questão=127
# Achou fim. questão=127. Total=127
#
#
# {'question_number': '128', 'question_summary': 'NÃO RESIDENTE - RENDIMENTOS RECEBIDOS NO BRASIL', 'question_text': 'Como são tributados os rendimentos recebidos no Brasil por não residente?', 'answer': []}
#
#
# Começo pergunta. questão=128
# Achou fim. questão=128. Total=128
#
#
# {'question_number': '129', 'question_summary': 'RESIDENTE NO BRASIL - RENDIMENTOS DO EXTERIOR', 'question_text': 'Como são tributados os rendimentos recebidos por residente no Brasil de fontes no exterior?', 'answer': []}
#
#
# Começo pergunta. questão=129
# Achou fim. questão=129. Total=129
#
#
# {'question_number': '130', 'question_summary': 'HERANÇA. AQUISIÇÃO DE DIREITO POR NÃO RESIDENTE', 'question_text': 'Qual é o tratamento tributário sobre o pagamento realizado a herdeiro não residente no Brasil', 'answer': []}
#
#
# Começo pergunta. questão=130
# Achou fim pergunta. questão=130
# Achou fim. questão=130. Total=130
#
#
# {'question_number': '131', 'question_summary': 'RENDIMENTOS DE PAÍS SEM ACORDO COM O BRASIL', 'question_text': 'Qual é o tratamento tributário dos rendimentos recebidos do exterior quando inexistir acordo', 'answer': []}
#
#
# Começo pergunta. questão=131
# Achou fim pergunta. questão=131
# Achou fim. questão=131. Total=131
#
#
# {'question_number': '132', 'question_summary': 'RESIDENTE', 'question_text': 'Como são tributados os benefícios ou resgates de previdência complementar e Fundo de', 'answer': []}
#
#
# Começo pergunta. questão=132
# Achou fim pergunta. questão=132
# Achou fim. questão=132. Total=132
#
#
# {'question_number': '133', 'question_summary': 'NÃO RESIDENTE – APOSENTADORIA E PENSÃO RECEBIDA NO BRASIL', 'question_text': 'Como são tributados os rendimentos recebidos, de fonte pagadora situada no Brasil, por não', 'answer': []}
#
#
# Começo pergunta. questão=133
# Achou fim pergunta. questão=133
# Achou fim. questão=133. Total=133
#
#
# {'question_number': '134', 'question_summary': 'TRABALHISTA', 'question_text': 'Como é feita a tributação dos rendimentos recebidos em reclamatória trabalhista, por não', 'answer': []}
#
#
# Começo pergunta. questão=134
# Achou fim pergunta. questão=134
# Achou fim. questão=134. Total=134
#
#
# {'question_number': '135', 'question_summary': 'RENDIMENTOS ORIUNDOS DE PAÍS QUE POSSUI ACORDO COM O BRASIL', 'question_text': 'Como são tributados os rendimentos de residente no Brasil recebidos do exterior na', 'answer': []}
#
#
# Começo pergunta. questão=135
# Achou fim pergunta. questão=135
# Achou fim. questão=135. Total=135
#
#
# {'question_number': '136', 'question_summary': 'ESTRANGEIRO - TRANSFERÊNCIA PARA O BRASIL', 'question_text': 'Qual é o tratamento tributário dos rendimentos recebidos no Brasil e no exterior por', 'answer': []}
#
#
# Começo pergunta. questão=136
# Achou fim pergunta. questão=136
# Achou fim. questão=136. Total=136
#
#
# {'question_number': '137', 'question_summary': 'RESIDENTE – LUCROS DE EMPRESAS DO EXTERIOR', 'question_text': 'Qual é o tratamento tributário dos lucros e dividendos recebidos por residente no Brasil de', 'answer': []}
#
#
# Começo pergunta. questão=137
# Achou fim pergunta. questão=137
# Achou fim. questão=137. Total=137
#
#
# {'question_number': '138', 'question_summary': 'CONVERSÃO EM REAIS – DEDUÇÕES', 'question_text': 'Como devem ser convertidos em reais os pagamentos dedutíveis realizados em moeda', 'answer': []}
#
#
# Começo pergunta. questão=138
# Achou fim pergunta. questão=138
# Achou fim. questão=138. Total=138
#
#
# {'question_number': '139', 'question_summary': 'IMPOSTO PAGO NO EXTERIOR – COMPENSAÇÃO/CONVERSÃO', 'question_text': 'O imposto sobre a renda cobrado pelo país de origem pode ser compensado no Brasil quando', 'answer': []}
#
#
# Começo pergunta. questão=139
# Achou fim pergunta. questão=139
# Achou fim. questão=139. Total=139
#
#
# {'question_number': '140', 'question_summary': 'IMPOSTO PAGO NO EXTERIOR - COMPENSAÇÃO MENSAL/ANUAL', 'question_text': 'O imposto pago no exterior pode ser compensado apenas com o imposto apurado na', 'answer': []}
#
#
# Começo pergunta. questão=140
# Achou fim pergunta. questão=140
# Achou fim. questão=140. Total=140
#
#
# {'question_number': '141', 'question_summary': 'COMPENSAÇÃO - ALEMANHA, ESTADOS UNIDOS E REINO UNIDO', 'question_text': 'É compensável no Brasil o imposto pago sobre rendimentos recebidos na Alemanha, nos', 'answer': []}
#
#
# Começo pergunta. questão=141
# Achou fim pergunta. questão=141
# Achou fim. questão=141. Total=141
#
#
# {'question_number': '142', 'question_summary': 'SERVIDOR DE REPRESENTAÇÃO DIPLOMÁTICA - NÃO RESIDENTE', 'question_text': 'Qual é o tratamento tributário dos rendimentos recebidos por servidor diplomático, consular,', 'answer': []}
#
#
# Começo pergunta. questão=142
# Achou fim pergunta. questão=142
# Achou fim. questão=142. Total=142
#
#
# {'question_number': '143', 'question_summary': 'FUNCIONÁRIO DE REPRESENTAÇÃO DIPLOMÁTICA', 'question_text': 'Qual é o tratamento tributário dos rendimentos recebidos por funcionário administrativo ou', 'answer': []}
#
#
# Começo pergunta. questão=143
# Achou fim pergunta. questão=143
# Achou fim. questão=143. Total=143
#
#
# {'question_number': '144', 'question_summary': 'EMPREGADO PARTICULAR - MISSÃO DIPLOMÁTICA', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por empregado particular de', 'answer': []}
#
#
# Começo pergunta. questão=144
# Achou fim pergunta. questão=144
# Achou fim. questão=144. Total=144
#
#
# {'question_number': '145', 'question_summary': 'EMPREGADO DE EMPRESAS ESTATAIS ESTRANGEIRAS NO BRASIL', 'question_text': 'Qual é o tratamento tributário dos rendimentos recebidos por empregado de empresas', 'answer': []}
#
#
# Começo pergunta. questão=145
# Achou fim pergunta. questão=145
# Achou fim. questão=145. Total=145
#
#
# {'question_number': '146', 'question_summary': 'RELIGIOSOS, MISSIONÁRIOS, PESQUISADORES E PROFESSORES', 'question_text': 'Religiosos, missionários, pesquisadores e professores não residentes, trabalhando no Brasil,', 'answer': []}
#
#
# Começo pergunta. questão=146
# Achou fim pergunta. questão=146
# Achou fim. questão=146. Total=146
#
#
# {'question_number': '147', 'question_summary': 'CIENTISTAS, PROFESSORES E PESQUISADORES', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por cientistas, professores,', 'answer': []}
#
#
# Começo pergunta. questão=147
# Achou fim pergunta. questão=147
# Achou fim. questão=147. Total=147
#
#
# {'question_number': '148', 'question_summary': 'RENDIMENTOS RECEBIDOS DE ORGANIZAÇÕES INTERNACIONAIS POR RESIDENTES NO BRASIL', 'question_text': 'Qual é o tratamento dos rendimentos auferidos por funcionário ou servidor residente no', 'answer': []}
#
#
# Começo pergunta. questão=148
# Achou fim pergunta. questão=148
# Achou fim. questão=148. Total=148
#
#
# {'question_number': '149', 'question_summary': 'PNUD', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário do Programa das', 'answer': []}
#
#
# Começo pergunta. questão=149
# Achou fim pergunta. questão=149
# Achou fim. questão=149. Total=149
#
#
# {'question_number': '150', 'question_summary': 'ONU E SUAS AGÊNCIAS ESPECIALIZADAS', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário da Organização das', 'answer': []}
#
#
# Começo pergunta. questão=150
# Achou fim pergunta. questão=150
# Achou fim. questão=150. Total=150
#
#
# {'question_number': '151', 'question_summary': 'ALADI', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário da Associação', 'answer': []}
#
#
# Começo pergunta. questão=151
# Achou fim pergunta. questão=151
# Achou fim. questão=151. Total=151
#
#
# {'question_number': '152', 'question_summary': 'OEA', 'question_text': 'Qual é o tratamento dos rendimentos recebidos por funcionário da Organização dos Estados', 'answer': []}
#
#
# Começo pergunta. questão=152
# Achou fim pergunta. questão=152
# Achou fim. questão=152. Total=152
#
#
# {'question_number': '153', 'question_summary': 'ORGANISMOS ESPECIALIZADOS DA OEA', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário dos Organismos', 'answer': []}
#
#
# Começo pergunta. questão=153
# Achou fim pergunta. questão=153
# Achou fim. questão=153. Total=153
#
#
# {'question_number': '154', 'question_summary': 'AEE', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário da Agência Espacial', 'answer': []}
#
#
# Começo pergunta. questão=154
# Achou fim pergunta. questão=154
# Achou fim. questão=154. Total=154
#
#
# {'question_number': '155', 'question_summary': 'RITLA DO SELA', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário da Rede de', 'answer': []}
#
#
# Começo pergunta. questão=155
# Achou fim pergunta. questão=155
# Achou fim. questão=155. Total=155
#
#
# {'question_number': '156', 'question_summary': 'INTELSAT', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário da Organização', 'answer': []}
#
#
# Começo pergunta. questão=156
# Achou fim pergunta. questão=156
# Achou fim. questão=156. Total=156
#
#
# {'question_number': '157', 'question_summary': 'OEI', 'question_text': 'Qual é o tratamento tributário relativo aos salários e emolumentos pagos pela Organização', 'answer': []}
#
#
# Começo pergunta. questão=157
# Achou fim pergunta. questão=157
# Achou fim. questão=157. Total=157
#
#
# {'question_number': '158', 'question_summary': 'CONSELHO DE COOPERAÇÃO ADUANEIRA', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário do Conselho de', 'answer': []}
#
#
# Começo pergunta. questão=158
# Achou fim pergunta. questão=158
# Achou fim. questão=158. Total=158
#
#
# {'question_number': '159', 'question_summary': 'CORPORAÇÃO INTERAMERICANA DE INVESTIMENTOS', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por funcionário da Corporação', 'answer': []}
#
#
# Começo pergunta. questão=159
# Achou fim pergunta. questão=159
# Achou fim. questão=159. Total=159
#
#
# {'question_number': '160', 'question_summary': 'NOVO BANCO DE DESENVOLVIMENTO (NDB)', 'question_text': 'Qual é o tratamento tributário dos rendimentos auferidos por diretores, suplentes, dirigentes', 'answer': []}
#
#
# Começo pergunta. questão=160
# Achou fim pergunta. questão=160
# Achou fim. questão=160. Total=160
#
#
# {'question_number': '161', 'question_summary': 'EX-FUNCIONÁRIO DE ORGANIZAÇÃO INTERNACIONAL', 'question_text': 'Qual é o tratamento tributário aplicado ao funcionário de organismo internacional a partir do', 'answer': []}
#
#
# Começo pergunta. questão=161
# Achou fim pergunta. questão=161
# Achou fim. questão=161. Total=161
#
#
# {'question_number': '162', 'question_summary': 'PESSOA FÍSICA A SERVIÇO DO BRASIL NO EXTERIOR - TRIBUTAÇÃO', 'question_text': 'Qual é o tratamento tributário para a pessoa física residente no Brasil, mas que se ausentou', 'answer': []}
#
#
# Começo pergunta. questão=162
# Achou fim pergunta. questão=162
# Achou fim. questão=162. Total=162
#
#
# {'question_number': '163', 'question_summary': 'PESSOA FÍSICA A SERVIÇO DO BRASIL NO EXTERIOR', 'question_text': 'Quem pode se enquadrar na condição de "a serviço do País no exterior" para usufruir dos', 'answer': []}
#
#
# Começo pergunta. questão=163
# Achou fim pergunta. questão=163
# Achou fim. questão=163. Total=163
#
#
# {'question_number': '164', 'question_summary': 'SERVIDOR PÚBLICO EM MISSÃO NO EXTERIOR', 'question_text': 'Como devem ser declarados os rendimentos do trabalho assalariado de servidor público, civil', 'answer': []}
#
#
# Começo pergunta. questão=164
# Achou fim pergunta. questão=164
# Achou fim. questão=164. Total=164
#
#
# {'question_number': '165', 'question_summary': 'TRANSFERÊNCIA DE RESIDÊNCIA - EXTERIOR', 'question_text': 'A pessoa física que se ausenta do país pode optar pela manutenção da condição de residente', 'answer': []}
#
#
# Começo pergunta. questão=165
# Achou fim pergunta. questão=165
# Achou fim. questão=165. Total=165
#
#
# {'question_number': '166', 'question_summary': 'RENDIMENTOS NO EXTERIOR', 'question_text': 'Como são tributados os rendimentos auferidos no exterior por residente no Brasil que saiu', 'answer': []}
#
#
# Começo pergunta. questão=166
# ...
#
#
# Começo pergunta. questão=660
# Achou fim pergunta. questão=660
# Achou fim. questão=660. Total=660
#
#
# {'question_number': '661', 'question_summary': 'ALIENAÇÃO DE PARTE DO IMÓVEL', 'question_text': 'Contribuinte, proprietário de um único imóvel, que não alienou nenhum imóvel nos últimos 5', 'answer': []}
#
#
# Começo pergunta. questão=661
# Achou fim pergunta. questão=661
# Achou fim. questão=661. Total=661
#
#
# {'question_number': '662', 'question_summary': 'ATIVOS RECEBIDOS - DISSOLUÇÃO SOCIEDADE CONJUGAL', 'question_text': 'Qual é o custo de aquisição na transferência de ativos recebidos na dissolução da sociedade', 'answer': []}
#
#
# Começo pergunta. questão=662
# Achou fim pergunta. questão=662
# Achou fim. questão=662. Total=662
#
#
# {'question_number': '663', 'question_summary': 'PAGAMENTO DO IR - DISSOLUÇÃO SOCIEDADE CONJUGAL', 'question_text': 'Quem é o contribuinte do imposto sobre o ganho de capital na transferência de ativos em', 'answer': []}
#
#
# Começo pergunta. questão=663
# Achou fim pergunta. questão=663
# Achou fim. questão=663. Total=663
#
#
# {'question_number': '664', 'question_summary': 'DOAÇÃO EM ADIANTAMENTO DA LEGÍTIMA - TRATAMENTO', 'question_text': 'Qual é o tratamento tributário na transferência de bens e direitos na doação em adiantamento', 'answer': []}
#
#
# Começo pergunta. questão=664
# Achou fim pergunta. questão=664
# Achou fim. questão=664. Total=664
#
#
# {'question_number': '665', 'question_summary': 'INCORPORAÇÃO DE PRÉDIOS EM CONDOMÍNIO', 'question_text': 'O que se considera como incorporação de prédios em condomínio?', 'answer': []}
#
#
# Começo pergunta. questão=665
# Achou fim. questão=665. Total=665
#
#
# {'question_number': '666', 'question_summary': 'CONSTRUÇÕES ABRANGIDAS PELAS INCORPORAÇÕES IMOBILIÁRIAS', 'question_text': 'Quais as construções abrangidas e a legislação que se aplica para as incorporações', 'answer': []}
#
#
# Começo pergunta. questão=666
# Achou fim pergunta. questão=666
# Achou fim. questão=666. Total=666
#
#
# {'question_number': '667', 'question_summary': 'INCORPORADOR', 'question_text': 'Quem é considerado "incorporador"?', 'answer': []}
#
#
# Começo pergunta. questão=667
# Achou fim. questão=667. Total=667
#
#
# {'question_number': '668', 'question_summary': 'LOTEAMENTO E DESMEMBRAMENTO DE TERRENOS', 'question_text': 'O que se considera como loteamento e desmembramento de terrenos?', 'answer': []}
#
#
# Começo pergunta. questão=668
# Achou fim. questão=668. Total=668
#
#
# {'question_number': '669', 'question_summary': 'PESSOA FÍSICA EQUIPARADA À JURÍDICA', 'question_text': 'A pessoa física equiparada a pessoa jurídica em razão de operações com imóveis, sofre dupla', 'answer': []}
#
#
# Começo pergunta. questão=669
# Achou fim pergunta. questão=669
# Achou fim. questão=669. Total=669
#
#
# {'question_number': '670', 'question_summary': 'FALECIMENTO DE INCORPORADOR', 'question_text': 'Na hipótese de falecimento de pessoa física equiparada a pessoa jurídica pela promoção de', 'answer': []}
#
#
# Começo pergunta. questão=670
# Achou fim pergunta. questão=670
# Achou fim. questão=670. Total=670
#
#
# {'question_number': '671', 'question_summary': 'RENDAS CONSIDERADAS CONSUMIDAS E DEDUÇÕES SEM COMPROVAÇÃO', 'question_text': 'As rendas consideradas consumidas e as deduções permitidas em lei, sem comprovação,', 'answer': []}
#
#
# Começo pergunta. questão=671
# Achou fim pergunta. questão=671
# Achou fim. questão=671. Total=671
#
#
# {'question_number': '672', 'question_summary': 'EMPRÉSTIMO - MÚTUO', 'question_text': 'Como declarar a quantia recebida como pagamento de empréstimo concedido?', 'answer': []}
#
#
# Começo pergunta. questão=672
# Achou fim. questão=672. Total=672
#
#
# {'question_number': '673', 'question_summary': 'TRANSAÇÕES ILÍCITAS', 'question_text': 'Acréscimo patrimonial oriundo de transações ilícitas é tributável?', 'answer': []}
#
#
# Começo pergunta. questão=673
# Achou fim. questão=673. Total=673
#
#
# {'question_number': '674', 'question_summary': 'GANHO LÍQUIDO', 'question_text': 'O que é ganho líquido nas operações em bolsa?', 'answer': []}
#
#
# Começo pergunta. questão=674
# Achou fim. questão=674. Total=674
#
#
# {'question_number': '675', 'question_summary': 'DAY TRADE - CONCEITO', 'question_text': 'O que é operação day trade?', 'answer': []}
#
#
# Começo pergunta. questão=675
# Achou fim. questão=675. Total=675
#
#
# {'question_number': '676', 'question_summary': '–OPERAÇÕES EM BOLSA - ALÍQUOTA/INCIDÊNCIA DO IR', 'question_text': 'Qual é a alíquota de incidência do IR aplicável nas operações realizadas em bolsa?', 'answer': []}
#
#
# Começo pergunta. questão=676
# Achou fim. questão=676. Total=676
#
#
# {'question_number': '677', 'question_summary': 'OPERAÇÕES EM BOLSA - ISENÇÃO', 'question_text': 'Quais operações em bolsa são isentas do IR?', 'answer': []}
#
#
# Começo pergunta. questão=677
# Achou fim. questão=677. Total=677
#
#
# {'question_number': '678', 'question_summary': 'OPERAÇÕES EM BOLSA - DEDUÇÕES', 'question_text': 'As despesas incorridas nas operações em bolsa podem ser deduzidas?', 'answer': []}
#
#
# Começo pergunta. questão=678
# Achou fim. questão=678. Total=678
#
#
# {'question_number': '679', 'question_summary': 'OPERAÇÕES EM BOLSA - COMPENSAÇÃO DE PERDAS', 'question_text': 'É permitida a compensação de perdas com os ganhos auferidos em operações realizadas em', 'answer': []}
#
#
# Começo pergunta. questão=679
# Achou fim pergunta. questão=679
# Achou fim. questão=679. Total=679
#
#
# {'question_number': '680', 'question_summary': 'OPERAÇÕES EM BOLSA - COMPENSAÇÃO DE PERDAS COM GANHOS DE MESES ANTERIORES', 'question_text': 'O resultado negativo ou perda apurado em um mês pode ser compensado com ganho auferido', 'answer': []}
#
#
# Começo pergunta. questão=680
# Achou fim pergunta. questão=680
# Achou fim. questão=680. Total=680
#
#
# {'question_number': '681', 'question_summary': 'PREJUÍZO EM DEZEMBRO - COMPENSAÇÃO', 'question_text': 'O resultado negativo ou perda apurado em dezembro pode ser compensado com o ganho', 'answer': []}
#
#
# Começo pergunta. questão=681
# Achou fim pergunta. questão=681
# Achou fim. questão=681. Total=681
#
#
# {'question_number': '682', 'question_summary': 'DAY TRADE - IMPOSTO SOBRE A RENDA INCIDENTE NA FONTE', 'question_text': 'Os rendimentos auferidos em operações day trade sujeitam-se à incidência do imposto sobre', 'answer': []}
#
#
# Começo pergunta. questão=682
# Achou fim pergunta. questão=682
# Achou fim. questão=682. Total=682
#
#
# {'question_number': '683', 'question_summary': 'DAY TRADE - RESPONSÁVEL PELA RETENÇÃO DO IR', 'question_text': 'Quem é o responsável pela retenção do imposto sobre a renda retido na fonte incidente sobre', 'answer': []}
#
#
# Começo pergunta. questão=683
# Achou fim pergunta. questão=683
# Achou fim. questão=683. Total=683
#
#
# {'question_number': '684', 'question_summary': 'DAY TRADE - COMPENSAÇÃO DO IR', 'question_text': 'O valor do imposto retido na fonte sobre as operações day trade pode ser deduzido do', 'answer': []}
#
#
# Começo pergunta. questão=684
# Achou fim pergunta. questão=684
# Achou fim. questão=684. Total=684
#
#
# {'question_number': '685', 'question_summary': 'DAY TRADE - COMPENSAÇÃO DO IR NO ANO-CALENDÁRIO SEGUINTE', 'question_text': 'O valor do imposto retido na fonte durante o ano-calendário sobre rendimentos de day trade', 'answer': []}
#
#
# Começo pergunta. questão=685
# Achou fim pergunta. questão=685
# Achou fim. questão=685. Total=685
#
#
# {'question_number': '686', 'question_summary': 'ALIENAÇÃO DE AÇÕES - OPERAÇÕES REALIZADAS FORA DE BOLSA', 'question_text': 'Qual é o tratamento tributário conferido aos ganhos obtidos nas alienações de ações fora de', 'answer': []}
#
#
# Começo pergunta. questão=686
# Achou fim pergunta. questão=686
# Achou fim. questão=686. Total=686
#
#
# {'question_number': '687', 'question_summary': 'COMPENSAÇÃO - OPERAÇÕES REALIZADAS DENTRO E FORA DE BOLSA', 'question_text': 'O resultado negativo obtido pela pessoa física na alienação de ações  fora de bolsa pode ser', 'answer': []}
#
#
# Começo pergunta. questão=687
# Achou fim pergunta. questão=687
# Achou fim. questão=687. Total=687
#
#
# {'question_number': '688', 'question_summary': 'MERCADO À VISTA - GANHO LÍQUIDO', 'question_text': 'Como se calcula o ganho líquido sobre operações nos mercados à vista?', 'answer': []}
#
#
# Começo pergunta. questão=688
# Achou fim. questão=688. Total=688
#
#
# {'question_number': '689', 'question_summary': 'MERCADO À VISTA - CUSTO DOS ATIVOS', 'question_text': 'Como se calcula o custo de aquisição dos ativos no mercado à vista?', 'answer': []}
#
#
# Começo pergunta. questão=689
# Achou fim. questão=689. Total=689
#
#
# {'question_number': '690', 'question_summary': 'INSTITUIÇÕES', 'question_text': 'Como se calcula o custo de aquisição de ações de mesma espécie negociadas no mercado à', 'answer': []}
#
#
# Começo pergunta. questão=690
# Achou fim pergunta. questão=690
# Achou fim. questão=690. Total=690
#
#
# {'question_number': '691', 'question_summary': 'CUSTO DE BONIFICAÇÕES', 'question_text': 'Qual é o custo de aquisição de bonificações recebidas em virtude de incorporação de lucros', 'answer': []}
#
#
# Começo pergunta. questão=691
# Achou fim pergunta. questão=691
# Achou fim. questão=691. Total=691
#
#
# {'question_number': '692', 'question_summary': 'CUSTO DE AQUISIÇÃO - AÇÕES DESDOBRADAS', 'question_text': 'Qual é o valor do custo de aquisição de ações desdobradas?', 'answer': []}
#
#
# Começo pergunta. questão=692
# Achou fim. questão=692. Total=692
#
#
# {'question_number': '693', 'question_summary': 'GANHO LÍQUIDO - MERCADO A TERMO', 'question_text': 'O que se considera ganho líquido no mercado a termo?', 'answer': []}
#
#
# Começo pergunta. questão=693
# Achou fim. questão=693. Total=693
#
#
# {'question_number': '694', 'question_summary': 'GANHO LÍQUIDO - MERCADO DE OPÇÕES', 'question_text': 'O que se considera ganho líquido no mercado de opções, no caso de operações que tenham', 'answer': []}
#
#
# Começo pergunta. questão=694
# Achou fim pergunta. questão=694
# Achou fim. questão=694. Total=694
#
#
# {'question_number': '695', 'question_summary': 'GANHO LÍQUIDO - EXERCÍCIO DE OPÇÕES DE COMPRA', 'question_text': 'O que se considera ganho líquido no exercício de opções de compra?', 'answer': []}
#
#
# Começo pergunta. questão=695
# Achou fim. questão=695. Total=695
#
#
# {'question_number': '696', 'question_summary': 'GANHO LÍQUIDO - EXERCÍCIO DE OPÇÕES DE VENDA', 'question_text': 'O que se considera ganho líquido no exercício de opções de venda?', 'answer': []}
#
#
# Começo pergunta. questão=696
# Achou fim. questão=696. Total=696
#
#
# {'question_number': '697', 'question_summary': 'PRÊMIO - NÃO EXERCÍCIO OU ENCERRAMENTO DA OPÇÃO', 'question_text': 'Qual é o tratamento dado ao valor do prêmio quando não ocorre o exercício ou o', 'answer': []}
#
#
# Começo pergunta. questão=697
# Achou fim pergunta. questão=697
# Achou fim. questão=697. Total=697
#
#
# {'question_number': '698', 'question_summary': 'GANHO LÍQUIDO - MERCADO FUTURO', 'question_text': 'O que se considera ganho líquido nos mercados futuros?', 'answer': []}
#
#
# Começo pergunta. questão=698
# Achou fim. questão=698. Total=698
#
#
# {'question_number': '699', 'question_summary': 'DEMONSTRATIVO DE APURAÇÃO DE GANHOS - RENDA VARIÁVEL - OBRIGATORIEDADE', 'question_text': 'Quem está obrigado a preencher o Demonstrativo de Apuração de Ganhos - Renda Variável?', 'answer': []}
#
#
# Começo pergunta. questão=699
# Achou fim. questão=699. Total=699
#
#
# {'question_number': '700', 'question_summary': 'PRAZO - PAGAMENTO DO IR', 'question_text': 'Qual é o prazo para o pagamento do IR sobre os ganhos líquidos auferidos no mercado', 'answer': []}
#
#
# Começo pergunta. questão=700
# Achou fim pergunta. questão=700
# Achou fim. questão=700. Total=700
#
#
# {'question_number': '701', 'question_summary': 'GANHOS EM OPERAÇÕES EM BOLSA - DECLARAÇÃO DE AJUSTE ANUAL', 'question_text': 'Os ganhos líquidos devem ser oferecidos à tributação na Declaração de Ajuste Anual?', 'answer': []}
#
#
# Começo pergunta. questão=701
# Achou fim. questão=701. Total=701
#
#
# {'question_number': '702', 'question_summary': 'FUNDOS DE AÇÕES', 'question_text': 'Como são tributados os ganhos obtidos pelos cotistas de fundos de ações?', 'answer': []}
#
#
# Começo pergunta. questão=702
# Achou fim. questão=702. Total=702
#
#
# {'question_number': '703', 'question_summary': 'OPERAÇÕES REALIZADAS POR NÃO RESIDENTE', 'question_text': 'Como são tributadas as operações no mercado de renda variável e de renda fixa realizadas', 'answer': []}
#
#
# Começo pergunta. questão=703
# Achou fim pergunta. questão=703
# Achou fim. questão=703. Total=703
#
#
# {'question_number': '704', 'question_summary': 'APLICAÇÃO FINANCEIRA', 'question_text': 'Qual é o tratamento tributário dos rendimentos obtidos pela pessoa física nas aplicações', 'answer': []}
#
#
# Começo pergunta. questão=704
# Achou fim pergunta. questão=704
# Achou fim. questão=704. Total=704
#
#
# {'question_number': '705', 'question_summary': 'COMPENSAÇÃO DO IMPOSTO SOBRE A RENDA RETIDO NA FONTE EM APLICAÇÃO FINANCEIRA', 'question_text': 'Pode ser compensado na Declaração de Ajuste Anual o imposto sobre a renda retido em', 'answer': []}
#
#
# Começo pergunta. questão=705
# Achou fim pergunta. questão=705
# Achou fim. questão=705. Total=705
#
#
# {'question_number': '706', 'question_summary': 'FUNDOS DE RENDA FIXA', 'question_text': 'Como são tributados os rendimentos obtidos pelos cotistas de fundos de renda fixa?', 'answer': []}
#
#
# Começo pergunta. questão=706
# Achou fim. questão=706. Total=706
#
#
# {'question_number': '707', 'question_summary': 'APLICAÇÃO EM BOLSA FEITA POR DUAS OU MAIS PESSOAS', 'question_text': 'Como devem ser tributadas as aplicações em bolsa efetuadas por duas ou mais pessoas?', 'answer': []}
#
#
# Começo pergunta. questão=707
# Achou fim. questão=707. Total=707
#
#
# {'question_number': '708', 'question_summary': 'RENDIMENTOS ISENTOS OU TRIBUTADOS À ALIQUOTA ZERO', 'question_text': 'Quais são os ativos que produzem rendimentos isentos ou tributados à alíquota zero de', 'answer': []}
#
#
# Começo pergunta. questão=708
# Achou fim pergunta. questão=708
# Achou fim. questão=708. Total=708
#
#
# {'question_number': '709', 'question_summary': 'TÍTULOS DE CAPITALIZAÇÃO', 'question_text': 'Como são tributados os rendimentos oriundos de títulos de capitalização?', 'answer': []}
#
#
# Começo pergunta. questão=709
# Achou fim. questão=709. Total=709
#
#
# {'question_number': '710', 'question_summary': 'GANHOS - COMPRA E VENDA DE OURO', 'question_text': 'Qual é o tratamento tributário dos ganhos em operações de compra e venda de ouro?', 'answer': []}
#
#
# Começo pergunta. questão=710
# Achou fim. questão=710. Total=710
#
#
# {'question_number': '711', 'question_summary': 'RENDIMENTOS – CONTA DE DEPÓSITO DE POUPANÇA', 'question_text': 'Qual é o tratamento tributário dos rendimentos produzidos por conta de depósito de', 'answer': []}
#
#
# Começo pergunta. questão=711
# Achou fim pergunta. questão=711
# Achou fim. questão=711. Total=711
#
#
# {'question_number': '712', 'question_summary': 'CONTA DE DEPÓSITO DE POUPANÇA - MENOR DE IDADE', 'question_text': 'Qual é o tratamento tributário dos rendimentos produzidos por conta de depósito de', 'answer': []}
#
#
# Começo pergunta. questão=712
# Achou fim pergunta. questão=712
# Achou fim. questão=712. Total=712
#
#
# {'question_number': '713', 'question_summary': 'JUROS DE POUPANÇA - NÃO RESIDENTE', 'question_text': 'As importâncias correspondentes aos juros de conta de depósito de poupança remetidas', 'answer': []}
#
#
# Começo pergunta. questão=713
# Achou fim pergunta. questão=713
# Achou fim. questão=713. Total=713
#
#
# {'question_number': '714', 'question_summary': 'AÇÕES LEILOADAS - PROGRAMA NACIONAL DE DESESTATIZAÇÃO', 'question_text': 'Qual é o tratamento tributário aplicável na aquisição de ações leiloadas no âmbito do', 'answer': []}
#
#
# Começo pergunta. questão=714
# Achou fim pergunta. questão=714
# Achou fim. questão=714. Total=714
#
#
# {'question_number': '715', 'question_summary': 'ALIENAÇÃO DE AÇÕES EM BOLSA - LIQUIDAÇÃO NO MÊS SUBSEQUENTE', 'question_text': 'No caso de alienação de ações em pregão ao final de determinado mês, que resulte em', 'answer': []}
#
#
# Começo pergunta. questão=715
# Achou fim pergunta. questão=715
# Achou fim. questão=715. Total=715

# %%
import json

file_path = "questions_and_anwers.txt"

# Write each dictionary as a JSON string in a new line
with open(file_path, 'w') as file:
    for item in questions:
        json.dump(item, file)
        file.write("\n")

print(f"Data saved to {file_path}")
# Out:
# Data saved to questions_and_anwers.txt
